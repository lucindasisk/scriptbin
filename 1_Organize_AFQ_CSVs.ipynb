# %%
import pandas as pd
from datetime import date
from os import makedirs, getcwd
from os.path import dirname, join
today=str(date.today())

# %%
##### EDIT THESE VARIABLES

tp='T2' # This is the timepoint for which you are running the script
sunet = 'sisklm' # This is the sunet of the person who ran AFQ)
newstem = 'rerun' # This is the stem you want to use to identify the files this script will produce -- I.E. 'Tmid_AllSubs'
stem='ELS-T2_AFQ_rerun_8.16.19' # This is the stem of the AFQ files you are organizing 
# For instance, if your AFQ output file is LS_AllSubs_TK1_Left_Arcuate.csv, the stem would be "LS_AllSubs_TK1"

##### DO NOT EDIT VARIABLES PAST THIS POINT

# %%
#Oak paths - used to strip off path from variable name
oakp1 = '/share/Oak/'+sunet+'/ELS_data/ELS_DTI_Analysis/ELS_{}/matproc/els'.format(tp)
oakp2 = '-{}/dti60trilin/'.format(tp)

path=getcwd()
pdir=dirname(path)
#home=join(pdir,'ELS_{}/matproc/AFQ_results'.format(tp))
home='/Volumes/iang/ELS_data/ELS_DTI_Analysis/ELS_{}/matproc/AFQ_results'.format(tp)

#Tracts from which we will be extracting
tracts = ['Arcuate','Cingulum_Cingulate','Cingulum_Hippocampus', 'Corticospinal', 'IFOF',
         'IFOF', 'ILF', 'SLF', 'Thalmic_Radiation', 'Uncinate']
hemisphere = ['Left', 'Right']
metrics = ['AD', 'FA', 'MD', 'RD']

#Read in Age CSV
age=pd.read_csv('/Volumes/iang/ELS_data/ELS_DTI_Analysis/DateAgeFiles/{}_Ages_Dates.csv'.format(tp),header=0).astype(str)
age.rename(columns={'Date of Scan':'Date.of.Scan.{}'.format(tp), 'Age at Scan':'Age.at.Scan.{}'.format(tp)}, inplace=True)

# %%
first_run = 'no'
for tract in tracts:
    try:
        makedirs(home+'/'+tract)
    except:
        pass
    for hemi in hemisphere:
        for metric in metrics:
            print('Cleaning data for {}_{}_{}_{}.csv'.format(stem,hemi,tract,metric))
            df = pd.read_csv(home + '/{}_{}_{}_{}.csv'.format(stem,hemi,tract,metric), header = None)
            df.iloc[:,0] = df.iloc[:,0].astype(str)
            rng = range(1, len(list(df)))
            new_cols = ['subject ID'] + ['{}.{}.{}.{}.node'.format(hemi,tract,metric,tp) + str(i) for i in rng] #+ ['expt_' + str(i) for i in rng]
            df.columns = new_cols
            df['subject ID']=df['subject ID'].str.replace(oakp1,'').str.replace('els','').str.replace(oakp2,'').str.replace('-{}'.format(tp),'').str.lstrip('0')
            df2 = pd.merge(age, df, on='subject ID', how='right').sort_values(by='subject ID')
            df2['{}.{}.{}.{}.mean'.format(hemi,tract,metric,tp)] = df2.iloc[:,3:103].mean(axis=1)
            if first_run == 'yes':
                try:
                    makedirs(home+'/'+tract+'/CLEAN_5.1.19')
                except:
                    pass
                df2.to_csv(home + '/{}/CLEAN_5.1.19/ELS_{}_Cleaned_{}_{}_{}_2019-05-01.csv'.format(tract,tp,hemi,tract,metric), index=False)
            elif first_run =='no':
                df2.to_csv(home + '/{}/ELS_{}_{}_Cleaned_{}_{}_{}_{}.csv'.format(tract,tp,newstem,hemi,tract,metric,today), index=False)
                print('New data saved to ELS_{}_{}_Cleaned_{}_{}_{}_{}.csv'.format(tract,tp,newstem,hemi,tract,metric,today))
# Out:
# Cleaning data for ELS-T2_AFQ_rerun_8.16.19_Left_Arcuate_AD.csv
# New data saved to ELS_Arcuate_T2_Cleaned_rerun_Left_Arcuate_AD.csv
# Cleaning data for ELS-T2_AFQ_rerun_8.16.19_Left_Arcuate_FA.csv
# New data saved to ELS_Arcuate_T2_Cleaned_rerun_Left_Arcuate_FA.csv
# Cleaning data for ELS-T2_AFQ_rerun_8.16.19_Left_
AD.csv
# Cleaning data for ELS-T2_AFQ_rerun_8.16.19_Right_Corticospinal_FA.csv
# New data saved to ELS_Corticospinal_T2_Cleaned_rerun_Right_Corticospinal_FA.csv
# Cleaning data for ELS-T2_AFQ_rerun_8.16.19_Right_Corticospinal_MD.csv
# New data saved to ELS_Corticospinal_T2_Cleaned_rerun_Right_Corticospinal_MD.csv
# Cleaning data for ELS-T2_AFQ_rerun_8.16.19_Right_Corticospinal_RD.csv
# New data saved to ELS_Corticospinal_T2_Cleaned_rerun_Right_Corticospinal_RD.csv
# Cleaning data for ELS-T2_AFQ_rerun_8.16.19_Left_IFOF_AD.csv
# New data saved to ELS_IFOF_T2_Cleaned_rerun_Left_IFOF_AD.csv
# Cleaning data for ELS-T2_AFQ_rerun_8.16.19_Left_IFOF_FA.csv
# New data saved to ELS_IFOF_T2_Cleaned_rerun_Left_IFOF_FA.csv
# Cleaning data for ELS-T2_AFQ_rerun_8.16.19_Left_IFOF_MD.csv
# New data saved to ELS_IFOF_T2_Cleaned_rerun_Left_IFOF_MD.csv
# Cleaning data for ELS-T2_AFQ_rerun_8.16.19_Left_IFOF_RD.csv
# New data saved to ELS_IFOF_T2_Cleaned_rerun_Left_IFOF_RD.csv
# Cleaning data for ELS-T2_AFQ_rerun_8.16.19_Right_IFOF_AD.csv
# New data saved to ELS_IFOF_T2_Cleaned_rerun_Right_IFOF_AD.csv
# Cleaning data for ELS-T2_AFQ_rerun_8.16.19_Right_IFOF_FA.csv
# New data saved to ELS_IFOF_T2_Cleaned_rerun_Right_IFOF_FA.csv
# Cleaning data for ELS-T2_AFQ_rerun_8.16.19_Right_IFOF_MD.csv
# New data saved to ELS_IFOF_T2_Cleaned_rerun_Right_IFOF_MD.csv
# Cleaning data for ELS-T2_AFQ_rerun_8.16.19_Right_IFOF_RD.csv
# New data saved to ELS_IFOF_T2_Cleaned_rerun_Right_IFOF_RD.csv
# Cleaning data for ELS-T2_AFQ_rerun_8.16.19_Left_IFOF_AD.csv
# New data saved to ELS_IFOF_T2_Cleaned_rerun_Left_IFOF_AD.csv
# Cleaning data for ELS-T2_AFQ_rerun_8.16.19_Left_IFOF_FA.csv
# New data saved to ELS_IFOF_T2_Cleaned_rerun_Left_IFOF_FA.csv
# Cleaning data for ELS-T2_AFQ_rerun_8.16.19_Left_IFOF_MD.csv
# New data saved to ELS_IFOF_T2_Cleaned_rerun_Left_IFOF_MD.csv
# Cleaning data for ELS-T2_AFQ_rerun_8.16.19_Left_IFOF_RD.csv
# New data saved to ELS_IFOF_T2_Cleaned_rerun_Left_IFOF_RD.csv
# Cleaning data for ELS-T2_AFQ_rerun_8.16.19_Right_IFOF_AD.csv
# New data saved to ELS_IFOF_T2_Cleaned_rerun_Right_IFOF_AD.csv
# Cleaning data for ELS-T2_AFQ_rerun_8.16.19_Right_IFOF_FA.csv
# New data saved to ELS_IFOF_T2_Cleaned_rerun_Right_IFOF_FA.csv
# Cleaning data for ELS-T2_AFQ_rerun_8.16.19_Right_IFOF_MD.csv
# New data saved to ELS_IFOF_T2_Cleaned_rerun_Right_IFOF_MD.csv
# Cleaning data for ELS-T2_AFQ_rerun_8.16.19_Right_IFOF_RD.csv
# New data saved to ELS_IFOF_T2_Cleaned_rerun_Right_IFOF_RD.csv
# Cleaning data for ELS-T2_AFQ_rerun_8.16.19_Left_ILF_AD.csv
# New data saved to ELS_ILF_T2_Cleaned_rerun_Left_ILF_AD.csv
# Cleaning data for ELS-T2_AFQ_rerun_8.16.19_Left_ILF_FA.csv
# New data saved to ELS_ILF_T2_Cleaned_rerun_Left_ILF_FA.csv
# Cleaning data for ELS-T2_AFQ_rerun_8.16.19_Left_ILF_MD.csv
# New data saved to ELS_ILF_T2_Cleaned_rerun_Left_ILF_MD.csv
# Cleaning data for ELS-T2_AFQ_rerun_8.16.19_Left_ILF_RD.csv
# New data saved to ELS_ILF_T2_Cleaned_rerun_Left_ILF_RD.csv
# Cleaning data for ELS-T2_AFQ_rerun_8.16.19_Right_ILF_AD.csv
# New data saved to ELS_ILF_T2_Cleaned_rerun_Right_ILF_AD.csv
# Cleaning data for ELS-T2_AFQ_rerun_8.16.19_Right_ILF_FA.csv
# New data saved to ELS_ILF_T2_Cleaned_rerun_Right_ILF_FA.csv
# Cleaning data for ELS-T2_AFQ_rerun_8.16.19_Right_ILF_MD.csv
# New data saved to ELS_ILF_T2_Cleaned_rerun_Right_ILF_MD.csv
# Cleaning data for ELS-T2_AFQ_rerun_8.16.19_Right_ILF_RD.csv
# New data saved to ELS_ILF_T2_Cleaned_rerun_Right_ILF_RD.csv
# Cleaning data for ELS-T2_AFQ_rerun_8.16.19_Left_SLF_AD.csv
# New data saved to ELS_SLF_T2_Cleaned_rerun_Left_SLF_AD.csv
# Cleaning data for ELS-T2_AFQ_rerun_8.16.19_Left_SLF_FA.csv
# New data saved to ELS_SLF_T2_Cleaned_rerun_Left_SLF_FA.csv
# Cleaning data for ELS-T2_AFQ_rerun_8.16.19_Left_SLF_MD.csv
# New data saved to ELS_SLF_T2_Cleaned_rerun_Left_SLF_MD.csv
# Cleaning data for ELS-T2_AFQ_rerun_8.16.19_Left_SLF_RD.csv
# New data saved to ELS_SLF_T2_Cleaned_rerun_Left_SLF_RD.csv
# Cleaning data for ELS-T2_AFQ_rerun_8.16.19_Right_SLF_AD.csv
# New data saved to ELS_SLF_T2_Cleaned_rerun_Right_SLF_AD.csv
# Cleaning data for ELS-T2_AFQ_rerun_8.16.19_Right_SLF_FA.csv
# New data saved to ELS_SLF_T2_Cleaned_rerun_Right_SLF_FA.csv
# Cleaning data for ELS-T2_AFQ_rerun_8.16.19_Right_SLF_MD.csv
# New data saved to ELS_SLF_T2_Cleaned_rerun_Right_SLF_MD.csv
# Cleaning data for ELS-T2_AFQ_rerun_8.16.19_Right_SLF_RD.csv
# New data saved to ELS_SLF_T2_Cleaned_rerun_Right_SLF_RD.csv
# Cleaning data for ELS-T2_AFQ_rerun_8.16.19_Left_Thalmic_Radiation_AD.csv
# New data saved to ELS_Thalmic_Radiation_T2_Cleaned_rerun_Left_Thalmic_Radiation_AD.csv
# Cleaning data for ELS-T2_AFQ_rerun_8.16.19_Left_Thalmic_Radiation_FA.csv
# New data saved to ELS_Thalmic_Radiation_T2_Cleaned_rerun_Left_Thalmic_Radiation_FA.csv
# Cleaning data for ELS-T2_AFQ_rerun_8.16.19_Left_Thalmic_Radiation_MD.csv
# New data saved to ELS_Thalmic_Radiation_T2_Cleaned_rerun_Left_Thalmic_Radiation_MD.csv
# Cleaning data for ELS-T2_AFQ_rerun_8.16.19_Left_Thalmic_Radiation_RD.csv
# New data saved to ELS_Thalmic_Radiation_T2_Cleaned_rerun_Left_Thalmic_Radiation_RD.csv
# Cleaning data for ELS-T2_AFQ_rerun_8.16.19_Right_Thalmic_Radiation_AD.csv
# New data saved to ELS_Thalmic_Radiation_T2_Cleaned_rerun_Right_Thalmic_Radiation_AD.csv
# Cleaning data for ELS-T2_AFQ_rerun_8.16.19_Right_Thalmic_Radiation_FA.csv
# New data saved to ELS_Thalmic_Radiation_T2_Cleaned_rerun_Right_Thalmic_Radiation_FA.csv
# Cleaning data for ELS-T2_AFQ_rerun_8.16.19_Right_Thalmic_Radiation_MD.csv
# New data saved to ELS_Thalmic_Radiation_T2_Cleaned_rerun_Right_Thalmic_Radiation_MD.csv
# Cleaning data for ELS-T2_AFQ_rerun_8.16.19_Right_Thalmic_Radiation_RD.csv
# New data saved to ELS_Thalmic_Radiation_T2_Cleaned_rerun_Right_Thalmic_Radiation_RD.csv
# Cleaning data for ELS-T2_AFQ_rerun_8.16.19_Left_Uncinate_AD.csv
# New data saved to ELS_Uncinate_T2_Cleaned_rerun_Left_Uncinate_AD.csv
# Cleaning data for ELS-T2_AFQ_rerun_8.16.19_Left_Uncinate_FA.csv
# New data saved to ELS_Uncinate_T2_Cleaned_rerun_Left_Uncinate_FA.csv
# Cleaning data for ELS-T2_AFQ_rerun_8.16.19_Left_Uncinate_MD.csv
# New data saved to ELS_Uncinate_T2_Cleaned_rerun_Left_Uncinate_MD.csv
# Cleaning data for ELS-T2_AFQ_rerun_8.16.19_Left_Uncinate_RD.csv
# New data saved to ELS_Uncinate_T2_Cleaned_rerun_Left_Uncinate_RD.csv
# Cleaning data for ELS-T2_AFQ_rerun_8.16.19_Right_Uncinate_AD.csv
# New data saved to ELS_Uncinate_T2_Cleaned_rerun_Right_Uncinate_AD.csv
# Cleaning data for ELS-T2_AFQ_rerun_8.16.19_Right_Uncinate_FA.csv
# New data saved to ELS_Uncinate_T2_Cleaned_rerun_Right_Uncinate_FA.csv
# Cleaning data for ELS-T2_AFQ_rerun_8.16.19_Right_Uncinate_MD.csv
# New data saved to ELS_Uncinate_T2_Cleaned_rerun_Right_Uncinate_MD.csv
# Cleaning data for ELS-T2_AFQ_rerun_8.16.19_Right_Uncinate_RD.csv
# New data saved to ELS_Uncinate_T2_Cleaned_rerun_Right_Uncinate_RD.csv

# %%
tract2 = ['Callosum_Forceps_Minor', 'Callosum_Forceps_Major']
for tract in tract2:
    try:
        makedirs(home+'/'+tract)
    except:
        print('Dir exists for {}'.format(tract))
    for metric in metrics:
            df = pd.read_csv(home + '/{}_{}_{}.csv'.format(stem,tract,metric), header = None)
            df.iloc[:,0] = df.iloc[:,0].astype(str)
            rng = range(1, len(list(df)))
            new_cols = ['subject ID'] + ['{}.{}.{}.node'.format(tract,metric,tp) + str(i) for i in rng] #+ ['expt_' + str(i) for i in rng]
            df.columns = new_cols
            df['subject ID']=df['subject ID'].str.replace(oakp1,'').str.replace('els','').str.replace(oakp2,'').str.replace('-{}'.format(tp),'').str.lstrip('0')
            df2 = pd.merge(age, df, on='subject ID', how='right').sort_values(by='subject ID')
            df2['{}.{}.{}.mean'.format(tract,metric,tp)] = df2.iloc[:,3:103].mean(axis=1)
            if first_run =='yes':
                try:
                    makedirs(home+'/'+tract+'/CLEAN_5.1.19')
                except:
                    print('CLEAN folder exists')
                df2.to_csv(home + '/{}/CLEAN_5.1.19/ELS_{}_Cleaned_{}_{}_2019-05-01.csv'.format(tract,tp,tract,metric), index=False)
            elif first_run =='no':
                df2.to_csv(home + '/{}/ELS_{}_{}_Cleaned_{}_{}_{}.csv'.format(tract,tp,newstem,tract,metric,today), index=False)
# Out:
# Dir exists for Callosum_Forceps_Minor
# Dir exists for Callosum_Forceps_Major

# %%
##Troubleshooting section - ignore

# tract='Arcuate'
# hemi='Left'
# metric='FA'

# df = pd.read_csv(home + '/{}_{}_{}_{}.csv'.format(stem,hemi,tract,metric), header = None)
# df.iloc[:,0] = df.iloc[:,0].astype(str)
# rng = range(1, len(list(df)))
# new_cols = ['subject ID'] + ['{}.{}.{}.{}.node'.format(hemi,tract,metric,tp) + str(i) for i in rng] #+ ['expt_' + str(i) for i in rng]
# df.columns = new_cols
# df['subject ID']=df['subject ID'].str.replace(oakp1,'').str.replace(oakp2,'').str.lstrip('0')
# df2 = pd.merge(age, df, on='subject ID', how='right').sort_values(by='subject ID')
# df2['{}.{}.{}.{}.mean'.format(hemi,tract,metric,tp)] = df2.iloc[:,3:103].mean(axis=1)
# #df2.to_csv(home + '/{}/ELS_{}_{}_Cleaned_{}_{}_{}_{}.csv'.format(tract,incsubs,tp,hemi,tract,metric,today), index=False)
# age.iloc[:,0] = age.iloc[:,0].astype(str)
# age.iloc[:,0]
