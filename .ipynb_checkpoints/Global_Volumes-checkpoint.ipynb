# %%
from os.path import join
from nipype import Node
from nipype.interfaces.fsl import ImageStats
from pandas import Series, DataFrame
from glob import glob
from datetime import date
# Out:
# /usr/local/anaconda3/lib/python3.6/importlib/_bootstrap.py:219: RuntimeWarning: numpy.dtype size changed, may indicate binary incompatibility. Expected 96, got 88
#   return f(*args, **kwds)
# /usr/local/anaconda3/lib/python3.6/site-packages/h5py/__init__.py:36: FutureWarning: Conversion of the second argument of issubdtype from `float` to `np.floating` is deprecated. In future, it will be treated as `np.float64 == np.dtype(float).type`.
#   from ._conv import register_converters as _register_converters

# %%
home = '/Volumes/group/active/BABIES/BABIES_ibeat/Segmentation/Segmented_IdeaLab'
data=[]
dest = '/Volumes/group/active/BABIES/BABIES_ibeat/data_output'
subject_list = glob(home + '/*_GMWM.nii.gz')
today = str(date.today())

# %%
def extract_vals(infile):
    sub = infile.replace(home + '/', '').replace('_GMWM.nii.gz', '').replace('-C-T1','').replace('-L-T3','')
    sep = ','
    
    fs_wm = Node(ImageStats(in_file = infile,
                       op_string = "-l 249 -u 251 -V"),
             name = 'fs_wm')
    fs_wm.run()
    wm_out1 = fs_wm.result.outputs
    wm_out = str(wm_out1).replace('\nout_stat = [','').split(sep, 1)[0]
    
    fs_gm = Node(ImageStats(in_file = infile,
                       op_string = "-l 149 -u 151 -V"),
             name = 'fs_gm')
    fs_gm.run()
    gm_out1 = fs_gm.result.outputs
    gm_out = str(gm_out1).replace('\nout_stat = [','').split(sep, 1)[0]
    
    fs_all = Node(ImageStats(in_file = infile,
                       op_string = "-l 149 -u 251 -V"),
             name = 'fs_gm')
    fs_all.run()
    all_out1 = fs_all.result.outputs
    all_out = str(all_out1).replace('\nout_stat = [','').split(sep, 1)[0]
    
    datasub = (sub, wm_out, gm_out, all_out)
    data.append(datasub)

# %%
for infile in subject_list:
    extract_vals(infile)
# Out:
# 190201-13:24:53,321 nipype.workflow INFO:
# 	 [Node] Setting-up "fs_wm" in "/private/var/folders/k9/m1nc7p5j71sfrw3hj1cg7jlr0000gn/T/tmp3493rsd8/fs_wm".
# 190201-13:24:53,325 nipype.workflow INFO:
# 	 [Node] Running "fs_wm" ("nipype.interfaces.fsl.utils.ImageStats"), a CommandLine Interface with command:
# fslstats /Volumes/group/active/BABIES/BABIES_ibeat/Segmentation/Segmented_IdeaLab/1029-L-T3_GMWM.nii.gz -l 249 -u 251 -V
# 190201-13:24:54,290 nipype.interface INFO:
# 	 stdout 2019-02-01T13:24:54.289993:265376 265376.000000
# 190201-13:24:54,404 nipype.workflow INFO:
# 	 [Node] Finished "fs_wm".
# 190201-13:24:54,408 nipype.workflow INFO:
# 	 [Node] Setting-up "fs_gm" in "/private/var/folders/k9/m1nc7p5j71sfrw3hj1cg7jlr0000gn/T/tmpezlkfng8/fs_gm".
# 190201-13:24:54,412 nipype.workflow INFO:
# 	 [Node] Running "fs_gm" ("nipype.interfaces.fsl.utils.ImageStats"), a CommandLine Interface with command:
# fslstats /Volumes/group/active/BABIES/BABIES_ibeat/Segmentation/Segmented_IdeaLab/1029-L-T3_GMWM.nii.gz -l 149 -u 151 -V
# 190201-13:24:55,356 nipype.interface INFO:
# 	 stdout 2019-02-01T13:24:55.355872:335670 335670.000000
# 190201-13:24:55,457 nipype.workflow INFO:
# 	 [Node] Finished "fs_gm".
# 190201-13:24:55,460 nipype.workflow INFO:
# 	 [Node] Setting-up "fs_gm" in "/private/var/folders/k9/m1nc7p5j71sfrw3hj1cg7jlr0000gn/T/tmpq405bm1w/fs_gm".
# 190201-13:24:55,464 nipype.workflow INFO:
# 	 [Node] Running "fs_gm" ("nipype.interfaces.fsl.utils.ImageStats"), a CommandLine Interface with command:
# fslstats /Volumes/group/active/BABIES/BABIES_ibeat/Segmentation/Segmented_IdeaLab/1029-L-T3_GMWM.nii.gz -l 149 -u 251 -V
# 190201-13:24:56,451 nipype.interface INFO:
# 	 stdout 2019-02-01T13:24:56.451028:601046 601046.000000
# 190201-13:24:56,560 nipype.workflow INFO:
# 	 [Node] Finished "fs_gm".
# 190201-13:24:56,565 nipype.workflow INFO:
# 	 [Node] Setting-up "fs_wm" in "/private/var/folders/k9/m1nc7p5j71sfrw3hj1cg7jlr0000gn/T/tmp8knowksx/fs_wm".
# 190201-13:24:56,569 nipype.workflow INFO:
# 	 [Node] Running "fs_wm" ("nipype.interfaces.fsl.utils.ImageStats"), a CommandLine Interface with command:
# fslstats /Volumes/group/active/BABIES/BABIES_ibeat/Segmentation/Segmented_IdeaLab/039-C-T1_GMWM.nii.gz -l 249 -u 251 -V
# 190201-13:24:57,519 nipype.interface INFO:
# 	 stdout 2019-02-01T13:24:57.519461:269027 269027.000000
# 190201-13:24:57,624 nipype.workflow INFO:
# 	 [Node] Finished "fs_wm".
# 190201-13:24:57,627 nipype.workflow INFO:
# 	 [Node] Setting-up "fs_gm" in "/private/var/folders/k9/m1nc7p5j71sfrw3hj1cg7jlr0000gn/T/tmp5dk38quk/fs_gm".
# 190201-13:24:57,631 nipype.workflow INFO:
# 	 [Node] Running "fs_gm" ("nipype.interfaces.fsl.utils.ImageStats"), a CommandLine Interface with command:
# fslstats /Volumes/group/active/BABIES/BABIES_ibeat/Segmentation/Segmented_IdeaLab/039-C-T1_GMWM.nii.gz -l 149 -u 151 -V
# 190201-13:24:58,563 nipype.interface INFO:
# 	 stdout 2019-02-01T13:24:58.563683:351881 351881.000000
# 190201-13:24:58,686 nipype.workflow INFO:
# 	 [Node] Finished "fs_gm".
# 190201-13:24:58,689 nipype.workflow INFO:
# 	 [Node] Setting-up "fs_gm" in "/private/var/folders/k9/m1nc7p5j71sfrw3hj1cg7jlr0000gn/T/tmpkxw579xk/fs_gm".
# 190201-13:24:58,694 nipype.workflow INFO:
# 	 [Node] Running "fs_gm" ("nipype.interfaces.fsl.utils.ImageStats"), a CommandLine Interface with command:
# fslstats /Volumes/group/active/BABIES/BABIES_ibeat/Segmentation/Segmented_IdeaLab/039-C-T1_GMWM.nii.gz -l 149 -u 251 -V
# 190201-13:24:59,616 nipype.interface INFO:
# 	 stdout 2019-02-01T13:24:59.616796:620908 620908.000000
# 190201-13:24:59,720 nipype.workflow INFO:
# 	 [Node] Finished "fs_gm".
# 190201-13:24:59,725 nipype.workflow INFO:
# 	 [Node] Setting-up "fs_wm" in "/private/var/folders/k9/m1nc7p5j71sfrw3hj1cg7jlr0000gn/T/tmp6az8yd2x/fs_wm".
# 190201-13:24:59,729 nipype.workflow INFO:
# 	 [Node] Running "fs_wm" ("nipype.interfaces.fsl.utils.ImageStats"), a CommandLine Interface with command:
# fslstats /Volumes/group/active/BABIES/BABIES_ibeat/Segmentation/Segmented_IdeaLab/012-C-T1_GMWM.nii.gz -l 249 -u 251 -V
# 190201-13:25:00,655 nipype.interface INFO:
# 	 stdout 2019-02-01T13:25:00.655020:294113 294113.000000
# 190201-13:25:00,765 nipype.workflow INFO:
# 	 [Node] Finished "fs_wm".
# 190201-13:25:00,768 nipype.workflow INFO:
# 	 [Node] Setting-up "fs_gm" in "/private/var/folders/k9/m1nc7p5j71sfrw3hj1cg7jlr0000gn/T/tmpiv99tu2d/fs_gm".
# 190201-13:25:00,772 nipype.workflow INFO:
# 	 [Node] Running "fs_gm" ("nipype.interfaces.fsl.utils.ImageStats"), a CommandLine Interface with command:
# fslstats /Volumes/group/active/BABIES/BABIES_ibeat/Segmentation/Segmented_IdeaLab/012-C-T1_GMWM.nii.gz -l 149 -u 151 -V
# 190201-13:25:01,703 nipype.interface INFO:
# 	 stdout 2019-02-01T13:25:01.703300:366166 366166.000000
# 190201-13:25:01,807 nipype.workflow INFO:
# 	 [Node] Finished "fs_gm".
# 190201-13:25:01,810 nipype.workflow INFO:
# 	 [Node] Setting-up "fs_gm" in "/private/var/folders/k9/m1nc7p5j71sfrw3hj1cg7jlr0000gn/T/tmp25j5xxar/fs_gm".
# 190201-13:25:01,814 nipype.workflow INFO:
# 	 [Node] Running "fs_gm" ("nipype.interfaces.fsl.utils.ImageStats"), a CommandLine Interface with command:
# fslstats /Volumes/group/active/BABIES/BABIES_ibeat/Segmentation/Segmented_IdeaLab/012-C-T1_GMWM.nii.gz -l 149 -u 251 -V
# 190201-13:25:02,739 nipype.interface INFO:
# 	 stdout 2019-02-01T13:25:02.738920:660279 660279.000000
# 190201-13:25:02,845 nipype.workflow INFO:
# 	 [Node] Finished "fs_gm".
# 190201-13:25:02,851 nipype.workflow INFO:
# 	 [Node] Setting-up "fs_wm" in "/private/var/folders/k9/m1nc7p5j71sfrw3hj1cg7jlr0000gn/T/tmpehhxsh6s/fs_wm".
# 190201-13:25:02,855 nipype.workflow INFO:
# 	 [Node] Running "fs_wm" ("nipype.interfaces.fsl.utils.ImageStats"), a CommandLine Interface with command:
# fslstats /Volumes/group/active/BABIES/BABIES_ibeat/Segmentation/Segmented_IdeaLab/109-C-T1_GMWM.nii.gz -l 249 -u 251 -V
# 190201-13:25:03,772 nipype.interface INFO:
# 	 stdout 2019-02-01T13:25:03.771963:300021 300021.000000
# 190201-13:25:03,880 nipype.workflow INFO:
# 	 [Node] Finished "fs_wm".
# 190201-13:25:03,883 nipype.workflow INFO:
# 	 [Node] Setting-up "fs_gm" in "/private/var/folders/k9/m1nc7p5j71sfrw3hj1cg7jlr0000gn/T/tmpu5au42d1/fs_gm".
# 190201-13:25:03,887 nipype.workflow INFO:
# 	 [Node] Running "fs_gm" ("nipype.interfaces.fsl.utils.ImageStats"), a CommandLine Interface with command:
# fslstats /Volumes/group/active/BABIES/BABIES_ibeat/Segmentation/Segmented_IdeaLab/109-C-T1_GMWM.nii.gz -l 149 -u 151 -V
# 190201-13:25:04,822 nipype.interface INFO:
# 	 stdout 2019-02-01T13:25:04.821918:376434 376434.000000
# 190201-13:25:04,927 nipype.workflow INFO:
# 	 [Node] Finished "fs_gm".
# 190201-13:25:04,929 nipype.workflow INFO:
# 	 [Node] Setting-up "fs_gm" in "/private/var/folders/k9/m1nc7p5j71sfrw3hj1cg7jlr0000gn/T/tmp2swo34sn/fs_gm".
# 190201-13:25:04,933 nipype.workflow INFO:
# 	 [Node] Running "fs_gm" ("nipype.interfaces.fsl.utils.ImageStats"), a CommandLine Interface with command:
# fslstats /Volumes/group/active/BABIES/BABIES_ibeat/Segmentation/Segmented_IdeaLab/109-C-T1_GMWM.nii.gz -l 149 -u 251 -V
# 190201-13:25:05,865 nipype.interface INFO:
# 	 stdout 2019-02-01T13:25:05.865583:676455 676455.000000
# 190201-13:25:05,966 nipype.workflow INFO:
# 	 [Node] Finished "fs_gm".
# 190201-13:25:05,971 nipype.workflow INFO:
# 	 [Node] Setting-up "fs_wm" in "/private/var/folders/k9/m1nc7p5j71sfrw3hj1cg7jlr0000gn/T/tmp8zbkedlo/fs_wm".
# 190201-13:25:05,976 nipype.workflow INFO:
# 	 [Node] Running "fs_wm" ("nipype.interfaces.fsl.utils.ImageStats"), a CommandLine Interface with command:
# fslstats /Volumes/group/active/BABIES/BABIES_ibeat/Segmentation/Segmented_IdeaLab/010-C-T1_GMWM.nii.gz -l 249 -u 251 -V
# 190201-13:25:06,896 nipype.interface INFO:
# 	 stdout 2019-02-01T13:25:06.896171:229504 229504.000000
# 190201-13:25:07,2 nipype.workflow INFO:
# 	 [Node] Finished "fs_wm".
# 190201-13:25:07,4 nipype.workflow INFO:
# 	 [Node] Setting-up "fs_gm" in "/private/var/folders/k9/m1nc7p5j71sfrw3hj1cg7jlr0000gn/T/tmpw5qsbenx/fs_gm".
# 190201-13:25:07,8 nipype.workflow INFO:
# 	 [Node] Running "fs_gm" ("nipype.interfaces.fsl.utils.ImageStats"), a CommandLine Interface with command:
# fslstats /Volumes/group/active/BABIES/BABIES_ibeat/Segmentation/Segmented_IdeaLab/010-C-T1_GMWM.nii.gz -l 149 -u 151 -V
# 190201-13:25:07,919 nipype.interface INFO:
# 	 stdout 2019-02-01T13:25:07.919516:296892 296892.000000
# 190201-13:25:08,26 nipype.workflow INFO:
# 	 [Node] Finished "fs_gm".
# 190201-13:25:08,29 nipype.workflow INFO:
# 	 [Node] Setting-up "fs_gm" in "/private/var/folders/k9/m1nc7p5j71sfrw3hj1cg7jlr0000gn/T/tmpens8qymq/fs_gm".
# 190201-13:25:08,33 nipype.workflow INFO:
# 	 [Node] Running "fs_gm" ("nipype.interfaces.fsl.utils.ImageStats"), a CommandLine Interface with command:
# fslstats /Volumes/group/active/BABIES/BABIES_ibeat/Segmentation/Segmented_IdeaLab/010-C-T1_GMWM.nii.gz -l 149 -u 251 -V
# 190201-13:25:08,955 nipype.interface INFO:
# 	 stdout 2019-02-01T13:25:08.954944:526396 526396.000000
# 190201-13:25:09,62 nipype.workflow INFO:
# 	 [Node] Finished "fs_gm".
# 190201-13:25:09,67 nipype.workflow INFO:
# 	 [Node] Setting-up "fs_wm" in "/private/var/folders/k9/m1nc7p5j71sfrw3hj1cg7jlr0000gn/T/tmpng0t9bsi/fs_wm".
# 190201-13:25:09,71 nipype.workflow INFO:
# 	 [Node] Running "fs_wm" ("nipype.interfaces.fsl.utils.ImageStats"), a CommandLine Interface with command:
# fslstats /Volumes/group/active/BABIES/BABIES_ibeat/Segmentation/Segmented_IdeaLab/108-C-T1_GMWM.nii.gz -l 249 -u 251 -V
# 190201-13:25:09,991 nipype.interface INFO:
# 	 stdout 2019-02-01T13:25:09.991638:286565 286565.000000
# 190201-13:25:10,96 nipype.workflow INFO:
# 	 [Node] Finished "fs_wm".
# 190201-13:25:10,99 nipype.workflow INFO:
# 	 [Node] Setting-up "fs_gm" in "/private/var/folders/k9/m1nc7p5j71sfrw3hj1cg7jlr0000gn/T/tmpcftg4xpc/fs_gm".
# 190201-13:25:10,103 nipype.workflow INFO:
# 	 [Node] Running "fs_gm" ("nipype.interfaces.fsl.utils.ImageStats"), a CommandLine Interface with command:
# fslstats /Volumes/group/active/BABIES/BABIES_ibeat/Segmentation/Segmented_IdeaLab/108-C-T1_GMWM.nii.gz -l 149 -u 151 -V
# 190201-13:25:11,30 nipype.interface INFO:
# 	 stdout 2019-02-01T13:25:11.030022:377634 377634.000000
# 190201-13:25:11,135 nipype.workflow INFO:
# 	 [Node] Finished "fs_gm".
# 190201-13:25:11,137 nipype.workflow INFO:
# 	 [Node] Setting-up "fs_gm" in "/private/var/folders/k9/m1nc7p5j71sfrw3hj1cg7jlr0000gn/T/tmpjmrk29ek/fs_gm".
# 190201-13:25:11,141 nipype.workflow INFO:
# 	 [Node] Running "fs_gm" ("nipype.interfaces.fsl.utils.ImageStats"), a CommandLine Interface with command:
# fslstats /Volumes/group/active/BABIES/BABIES_ibeat/Segmentation/Segmented_IdeaLab/108-C-T1_GMWM.nii.gz -l 149 -u 251 -V
# 190201-13:25:12,60 nipype.interface INFO:
# 	 stdout 2019-02-01T13:25:12.060528:664199 664199.000000
# 190201-13:25:12,166 nipype.workflow INFO:
# 	 [Node] Finished "fs_gm".
# 190201-13:25:12,171 nipype.workflow INFO:
# 	 [Node] Setting-up "fs_wm" in "/private/var/folders/k9/m1nc7p5j71sfrw3hj1cg7jlr0000gn/T/tmpmlpaxnf1/fs_wm".
# 190201-13:25:12,174 nipype.workflow INFO:
# 	 [Node] Running "fs_wm" ("nipype.interfaces.fsl.utils.ImageStats"), a CommandLine Interface with command:
# fslstats /Volumes/group/active/BABIES/BABIES_ibeat/Segmentation/Segmented_IdeaLab/002-C-T1_GMWM.nii.gz -l 249 -u 251 -V
# 190201-13:25:13,100 nipype.interface INFO:
# 	 stdout 2019-02-01T13:25:13.100631:280119 280119.000000
# 190201-13:25:13,207 nipype.workflow INFO:
# 	 [Node] Finished "fs_wm".
# 190201-13:25:13,210 nipype.workflow INFO:
# 	 [Node] Setting-up "fs_gm" in "/private/var/folders/k9/m1nc7p5j71sfrw3hj1cg7jlr0000gn/T/tmpqrmt29ie/fs_gm".
# 190201-13:25:13,214 nipype.workflow INFO:
# 	 [Node] Running "fs_gm" ("nipype.interfaces.fsl.utils.ImageStats"), a CommandLine Interface with command:
# fslstats /Volumes/group/active/BABIES/BABIES_ibeat/Segmentation/Segmented_IdeaLab/002-C-T1_GMWM.nii.gz -l 149 -u 151 -V
# 190201-13:25:14,131 nipype.interface INFO:
# 	 stdout 2019-02-01T13:25:14.131416:359841 359841.000000
# 190201-13:25:14,235 nipype.workflow INFO:
# 	 [Node] Finished "fs_gm".
# 190201-13:25:14,238 nipype.workflow INFO:
# 	 [Node] Setting-up "fs_gm" in "/private/var/folders/k9/m1nc7p5j71sfrw3hj1cg7jlr0000gn/T/tmpug_ywb5d/fs_gm".
# 190201-13:25:14,242 nipype.workflow INFO:
# 	 [Node] Running "fs_gm" ("nipype.interfaces.fsl.utils.ImageStats"), a CommandLine Interface with command:
# fslstats /Volumes/group/active/BABIES/BABIES_ibeat/Segmentation/Segmented_IdeaLab/002-C-T1_GMWM.nii.gz -l 149 -u 251 -V
# 190201-13:25:15,152 nipype.interface INFO:
# 	 stdout 2019-02-01T13:25:15.152595:639960 639960.000000
# 190201-13:25:15,278 nipype.workflow INFO:
# 	 [Node] Finished "fs_gm".
# 190201-13:25:15,287 nipype.workflow INFO:
# 	 [Node] Setting-up "fs_wm" in "/private/var/folders/k9/m1nc7p5j71sfrw3hj1cg7jlr0000gn/T/tmpscyvmp_c/fs_wm".
# 190201-13:25:15,293 nipype.workflow INFO:
# 	 [Node] Running "fs_wm" ("nipype.interfaces.fsl.utils.ImageStats"), a CommandLine Interface with command:
# fslstats /Volumes/group/active/BABIES/BABIES_ibeat/Segmentation/Segmented_IdeaLab/124-C-T1_GMWM.nii.gz -l 249 -u 251 -V
# 190201-13:25:16,246 nipype.interface INFO:
# 	 stdout 2019-02-01T13:25:16.246173:279667 279667.000000
# 190201-13:25:16,352 nipype.workflow INFO:
# 	 [Node] Finished "fs_wm".
# 190201-13:25:16,355 nipype.workflow INFO:
# 	 [Node] Setting-up "fs_gm" in "/private/var/folders/k9/m1nc7p5j71sfrw3hj1cg7jlr0000gn/T/tmp9mnb2_6z/fs_gm".
# 190201-13:25:16,359 nipype.workflow INFO:
# 	 [Node] Running "fs_gm" ("nipype.interfaces.fsl.utils.ImageStats"), a CommandLine Interface with command:
# fslstats /Volumes/group/active/BABIES/BABIES_ibeat/Segmentation/Segmented_IdeaLab/124-C-T1_GMWM.nii.gz -l 149 -u 151 -V
# 190201-13:25:17,311 nipype.interface INFO:
# 	 stdout 2019-02-01T13:25:17.310971:367459 367459.000000
# 190201-13:25:17,423 nipype.workflow INFO:
# 	 [Node] Finished "fs_gm".
# 190201-13:25:17,425 nipype.workflow INFO:
# 	 [Node] Setting-up "fs_gm" in "/private/var/folders/k9/m1nc7p5j71sfrw3hj1cg7jlr0000gn/T/tmp6nvh595r/fs_gm".
# 190201-13:25:17,429 nipype.workflow INFO:
# 	 [Node] Running "fs_gm" ("nipype.interfaces.fsl.utils.ImageStats"), a CommandLine Interface with command:
# fslstats /Volumes/group/active/BABIES/BABIES_ibeat/Segmentation/Segmented_IdeaLab/124-C-T1_GMWM.nii.gz -l 149 -u 251 -V
# 190201-13:25:18,365 nipype.interface INFO:
# 	 stdout 2019-02-01T13:25:18.365087:647126 647126.000000
# 190201-13:25:18,477 nipype.workflow INFO:
# 	 [Node] Finished "fs_gm".
# 190201-13:25:18,482 nipype.workflow INFO:
# 	 [Node] Setting-up "fs_wm" in "/private/var/folders/k9/m1nc7p5j71sfrw3hj1cg7jlr0000gn/T/tmpfvznfolb/fs_wm".
# 190201-13:25:18,486 nipype.workflow INFO:
# 	 [Node] Running "fs_wm" ("nipype.interfaces.fsl.utils.ImageStats"), a CommandLine Interface with command:
# fslstats /Volumes/group/active/BABIES/BABIES_ibeat/Segmentation/Segmented_IdeaLab/132-C-T1_GMWM.nii.gz -l 249 -u 251 -V
# 190201-13:25:19,408 nipype.interface INFO:
# 	 stdout 2019-02-01T13:25:19.408192:293680 293680.000000
# 190201-13:25:19,515 nipype.workflow INFO:
# 	 [Node] Finished "fs_wm".
# 190201-13:25:19,517 nipype.workflow INFO:
# 	 [Node] Setting-up "fs_gm" in "/private/var/folders/k9/m1nc7p5j71sfrw3hj1cg7jlr0000gn/T/tmpnyl63q0a/fs_gm".
# 190201-13:25:19,521 nipype.workflow INFO:
# 	 [Node] Running "fs_gm" ("nipype.interfaces.fsl.utils.ImageStats"), a CommandLine Interface with command:
# fslstats /Volumes/group/active/BABIES/BABIES_ibeat/Segmentation/Segmented_IdeaLab/132-C-T1_GMWM.nii.gz -l 149 -u 151 -V
# 190201-13:25:20,455 nipype.interface INFO:
# 	 stdout 2019-02-01T13:25:20.455619:359583 359583.000000
# 190201-13:25:20,571 nipype.workflow INFO:
# 	 [Node] Finished "fs_gm".
# 190201-13:25:20,573 nipype.workflow INFO:
# 	 [Node] Setting-up "fs_gm" in "/private/var/folders/k9/m1nc7p5j71sfrw3hj1cg7jlr0000gn/T/tmpxtgy_9r4/fs_gm".
# 190201-13:25:20,577 nipype.workflow INFO:
# 	 [Node] Running "fs_gm" ("nipype.interfaces.fsl.utils.ImageStats"), a CommandLine Interface with command:
# fslstats /Volumes/group/active/BABIES/BABIES_ibeat/Segmentation/Segmented_IdeaLab/132-C-T1_GMWM.nii.gz -l 149 -u 251 -V
# 190201-13:25:21,511 nipype.interface INFO:
# 	 stdout 2019-02-01T13:25:21.511097:653263 653263.000000
# 190201-13:25:21,616 nipype.workflow INFO:
# 	 [Node] Finished "fs_gm".
# 190201-13:25:21,621 nipype.workflow INFO:
# 	 [Node] Setting-up "fs_wm" in "/private/var/folders/k9/m1nc7p5j71sfrw3hj1cg7jlr0000gn/T/tmp98dkb5mg/fs_wm".
# 190201-13:25:21,625 nipype.workflow INFO:
# 	 [Node] Running "fs_wm" ("nipype.interfaces.fsl.utils.ImageStats"), a CommandLine Interface with command:
# fslstats /Volumes/group/active/BABIES/BABIES_ibeat/Segmentation/Segmented_IdeaLab/1036-L-T3_GMWM.nii.gz -l 249 -u 251 -V
# 190201-13:25:22,547 nipype.interface INFO:
# 	 stdout 2019-02-01T13:25:22.547398:299635 299635.000000
# 190201-13:25:22,651 nipype.workflow INFO:
# 	 [Node] Finished "fs_wm".
# 190201-13:25:22,654 nipype.workflow INFO:
# 	 [Node] Setting-up "fs_gm" in "/private/var/folders/k9/m1nc7p5j71sfrw3hj1cg7jlr0000gn/T/tmp2si8d0_2/fs_gm".
# 190201-13:25:22,658 nipype.workflow INFO:
# 	 [Node] Running "fs_gm" ("nipype.interfaces.fsl.utils.ImageStats"), a CommandLine Interface with command:
# fslstats /Volumes/group/active/BABIES/BABIES_ibeat/Segmentation/Segmented_IdeaLab/1036-L-T3_GMWM.nii.gz -l 149 -u 151 -V
# 190201-13:25:23,586 nipype.interface INFO:
# 	 stdout 2019-02-01T13:25:23.585894:386244 386244.000000
# 190201-13:25:23,691 nipype.workflow INFO:
# 	 [Node] Finished "fs_gm".
# 190201-13:25:23,694 nipype.workflow INFO:
# 	 [Node] Setting-up "fs_gm" in "/private/var/folders/k9/m1nc7p5j71sfrw3hj1cg7jlr0000gn/T/tmpmqcy49z9/fs_gm".
# 190201-13:25:23,698 nipype.workflow INFO:
# 	 [Node] Running "fs_gm" ("nipype.interfaces.fsl.utils.ImageStats"), a CommandLine Interface with command:
# fslstats /Volumes/group/active/BABIES/BABIES_ibeat/Segmentation/Segmented_IdeaLab/1036-L-T3_GMWM.nii.gz -l 149 -u 251 -V
# 190201-13:25:24,613 nipype.interface INFO:
# 	 stdout 2019-02-01T13:25:24.612977:685879 685879.000000
# 190201-13:25:24,724 nipype.workflow INFO:
# 	 [Node] Finished "fs_gm".
# 190201-13:25:24,728 nipype.workflow INFO:
# 	 [Node] Setting-up "fs_wm" in "/private/var/folders/k9/m1nc7p5j71sfrw3hj1cg7jlr0000gn/T/tmptyerbq90/fs_wm".
# 190201-13:25:24,732 nipype.workflow INFO:
# 	 [Node] Running "fs_wm" ("nipype.interfaces.fsl.utils.ImageStats"), a CommandLine Interface with command:
# fslstats /Volumes/group/active/BABIES/BABIES_ibeat/Segmentation/Segmented_IdeaLab/032-C-T1_GMWM.nii.gz -l 249 -u 251 -V
# 190201-13:25:25,713 nipype.interface INFO:
# 	 stdout 2019-02-01T13:25:25.713016:265910 265910.000000
# 190201-13:25:25,828 nipype.workflow INFO:
# 	 [Node] Finished "fs_wm".
# 190201-13:25:25,830 nipype.workflow INFO:
# 	 [Node] Setting-up "fs_gm" in "/private/var/folders/k9/m1nc7p5j71sfrw3hj1cg7jlr0000gn/T/tmpqf019h9p/fs_gm".
# 190201-13:25:25,835 nipype.workflow INFO:
# 	 [Node] Running "fs_gm" ("nipype.interfaces.fsl.utils.ImageStats"), a CommandLine Interface with command:
# fslstats /Volumes/group/active/BABIES/BABIES_ibeat/Segmentation/Segmented_IdeaLab/032-C-T1_GMWM.nii.gz -l 149 -u 151 -V
# 190201-13:25:26,804 nipype.interface INFO:
# 	 stdout 2019-02-01T13:25:26.804629:333635 333635.000000
# 190201-13:25:26,923 nipype.workflow INFO:
# 	 [Node] Finished "fs_gm".
# 190201-13:25:26,926 nipype.workflow INFO:
# 	 [Node] Setting-up "fs_gm" in "/private/var/folders/k9/m1nc7p5j71sfrw3hj1cg7jlr0000gn/T/tmp2d3_7x06/fs_gm".
# 190201-13:25:26,931 nipype.workflow INFO:
# 	 [Node] Running "fs_gm" ("nipype.interfaces.fsl.utils.ImageStats"), a CommandLine Interface with command:
# fslstats /Volumes/group/active/BABIES/BABIES_ibeat/Segmentation/Segmented_IdeaLab/032-C-T1_GMWM.nii.gz -l 149 -u 251 -V
# 190201-13:25:27,898 nipype.interface INFO:
# 	 stdout 2019-02-01T13:25:27.898079:599545 599545.000000
# 190201-13:25:28,6 nipype.workflow INFO:
# 	 [Node] Finished "fs_gm".
# 190201-13:25:28,10 nipype.workflow INFO:
# 	 [Node] Setting-up "fs_wm" in "/private/var/folders/k9/m1nc7p5j71sfrw3hj1cg7jlr0000gn/T/tmp0fnr0nl9/fs_wm".
# 190201-13:25:28,14 nipype.workflow INFO:
# 	 [Node] Running "fs_wm" ("nipype.interfaces.fsl.utils.ImageStats"), a CommandLine Interface with command:
# fslstats /Volumes/group/active/BABIES/BABIES_ibeat/Segmentation/Segmented_IdeaLab/027-C-T1_GMWM.nii.gz -l 249 -u 251 -V
# 190201-13:25:28,940 nipype.interface INFO:
# 	 stdout 2019-02-01T13:25:28.939951:249716 249716.000000
# 190201-13:25:29,48 nipype.workflow INFO:
# 	 [Node] Finished "fs_wm".
# 190201-13:25:29,50 nipype.workflow INFO:
# 	 [Node] Setting-up "fs_gm" in "/private/var/folders/k9/m1nc7p5j71sfrw3hj1cg7jlr0000gn/T/tmp4ec70ckz/fs_gm".
# 190201-13:25:29,55 nipype.workflow INFO:
# 	 [Node] Running "fs_gm" ("nipype.interfaces.fsl.utils.ImageStats"), a CommandLine Interface with command:
# fslstats /Volumes/group/active/BABIES/BABIES_ibeat/Segmentation/Segmented_IdeaLab/027-C-T1_GMWM.nii.gz -l 149 -u 151 -V
# 190201-13:25:29,991 nipype.interface INFO:
# 	 stdout 2019-02-01T13:25:29.991530:313682 313682.000000
# 190201-13:25:30,103 nipype.workflow INFO:
# 	 [Node] Finished "fs_gm".
# 190201-13:25:30,106 nipype.workflow INFO:
# 	 [Node] Setting-up "fs_gm" in "/private/var/folders/k9/m1nc7p5j71sfrw3hj1cg7jlr0000gn/T/tmpgscx2fp5/fs_gm".
# 190201-13:25:30,110 nipype.workflow INFO:
# 	 [Node] Running "fs_gm" ("nipype.interfaces.fsl.utils.ImageStats"), a CommandLine Interface with command:
# fslstats /Volumes/group/active/BABIES/BABIES_ibeat/Segmentation/Segmented_IdeaLab/027-C-T1_GMWM.nii.gz -l 149 -u 251 -V
# 190201-13:25:31,48 nipype.interface INFO:
# 	 stdout 2019-02-01T13:25:31.048470:563398 563398.000000
# 190201-13:25:31,156 nipype.workflow INFO:
# 	 [Node] Finished "fs_gm".
# 190201-13:25:31,161 nipype.workflow INFO:
# 	 [Node] Setting-up "fs_wm" in "/private/var/folders/k9/m1nc7p5j71sfrw3hj1cg7jlr0000gn/T/tmpmrze3pq8/fs_wm".
# 190201-13:25:31,165 nipype.workflow INFO:
# 	 [Node] Running "fs_wm" ("nipype.interfaces.fsl.utils.ImageStats"), a CommandLine Interface with command:
# fslstats /Volumes/group/active/BABIES/BABIES_ibeat/Segmentation/Segmented_IdeaLab/033-C-T1_GMWM.nii.gz -l 249 -u 251 -V
# 190201-13:25:32,87 nipype.interface INFO:
# 	 stdout 2019-02-01T13:25:32.086973:243455 243455.000000
# 190201-13:25:32,196 nipype.workflow INFO:
# 	 [Node] Finished "fs_wm".
# 190201-13:25:32,199 nipype.workflow INFO:
# 	 [Node] Setting-up "fs_gm" in "/private/var/folders/k9/m1nc7p5j71sfrw3hj1cg7jlr0000gn/T/tmpetqoyus6/fs_gm".
# 190201-13:25:32,203 nipype.workflow INFO:
# 	 [Node] Running "fs_gm" ("nipype.interfaces.fsl.utils.ImageStats"), a CommandLine Interface with command:
# fslstats /Volumes/group/active/BABIES/BABIES_ibeat/Segmentation/Segmented_IdeaLab/033-C-T1_GMWM.nii.gz -l 149 -u 151 -V
# 190201-13:25:33,105 nipype.interface INFO:
# 	 stdout 2019-02-01T13:25:33.105543:316290 316290.000000
# 190201-13:25:33,217 nipype.workflow INFO:
# 	 [Node] Finished "fs_gm".
# 190201-13:25:33,220 nipype.workflow INFO:
# 	 [Node] Setting-up "fs_gm" in "/private/var/folders/k9/m1nc7p5j71sfrw3hj1cg7jlr0000gn/T/tmp_lgwibjq/fs_gm".
# 190201-13:25:33,226 nipype.workflow INFO:
# 	 [Node] Running "fs_gm" ("nipype.interfaces.fsl.utils.ImageStats"), a CommandLine Interface with command:
# fslstats /Volumes/group/active/BABIES/BABIES_ibeat/Segmentation/Segmented_IdeaLab/033-C-T1_GMWM.nii.gz -l 149 -u 251 -V
# 190201-13:25:34,142 nipype.interface INFO:
# 	 stdout 2019-02-01T13:25:34.142463:559745 559745.000000
# 190201-13:25:34,247 nipype.workflow INFO:
# 	 [Node] Finished "fs_gm".
# 190201-13:25:34,252 nipype.workflow INFO:
# 	 [Node] Setting-up "fs_wm" in "/private/var/folders/k9/m1nc7p5j71sfrw3hj1cg7jlr0000gn/T/tmpjdqmk6bu/fs_wm".
# 190201-13:25:34,257 nipype.workflow INFO:
# 	 [Node] Running "fs_wm" ("nipype.interfaces.fsl.utils.ImageStats"), a CommandLine Interface with command:
# fslstats /Volumes/group/active/BABIES/BABIES_ibeat/Segmentation/Segmented_IdeaLab/115-C-T1_GMWM.nii.gz -l 249 -u 251 -V
# 190201-13:25:35,179 nipype.interface INFO:
# 	 stdout 2019-02-01T13:25:35.179236:278323 278323.000000
# 190201-13:25:35,290 nipype.workflow INFO:
# 	 [Node] Finished "fs_wm".
# 190201-13:25:35,293 nipype.workflow INFO:
# 	 [Node] Setting-up "fs_gm" in "/private/var/folders/k9/m1nc7p5j71sfrw3hj1cg7jlr0000gn/T/tmpgiibgjs2/fs_gm".
# 190201-13:25:35,297 nipype.workflow INFO:
# 	 [Node] Running "fs_gm" ("nipype.interfaces.fsl.utils.ImageStats"), a CommandLine Interface with command:
# fslstats /Volumes/group/active/BABIES/BABIES_ibeat/Segmentation/Segmented_IdeaLab/115-C-T1_GMWM.nii.gz -l 149 -u 151 -V
# 190201-13:25:36,309 nipype.interface INFO:
# 	 stdout 2019-02-01T13:25:36.309738:361418 361418.000000
# 190201-13:25:36,414 nipype.workflow INFO:
# 	 [Node] Finished "fs_gm".
# 190201-13:25:36,416 nipype.workflow INFO:
# 	 [Node] Setting-up "fs_gm" in "/private/var/folders/k9/m1nc7p5j71sfrw3hj1cg7jlr0000gn/T/tmphy2k2dd7/fs_gm".
# 190201-13:25:36,420 nipype.workflow INFO:
# 	 [Node] Running "fs_gm" ("nipype.interfaces.fsl.utils.ImageStats"), a CommandLine Interface with command:
# fslstats /Volumes/group/active/BABIES/BABIES_ibeat/Segmentation/Segmented_IdeaLab/115-C-T1_GMWM.nii.gz -l 149 -u 251 -V
# 190201-13:25:37,354 nipype.interface INFO:
# 	 stdout 2019-02-01T13:25:37.354065:639741 639741.000000
# 190201-13:25:37,459 nipype.workflow INFO:
# 	 [Node] Finished "fs_gm".
# 190201-13:25:37,464 nipype.workflow INFO:
# 	 [Node] Setting-up "fs_wm" in "/private/var/folders/k9/m1nc7p5j71sfrw3hj1cg7jlr0000gn/T/tmpe_evrqq5/fs_wm".
# 190201-13:25:37,470 nipype.workflow INFO:
# 	 [Node] Running "fs_wm" ("nipype.interfaces.fsl.utils.ImageStats"), a CommandLine Interface with command:
# fslstats /Volumes/group/active/BABIES/BABIES_ibeat/Segmentation/Segmented_IdeaLab/045-C-T1_GMWM.nii.gz -l 249 -u 251 -V
# 190201-13:25:38,409 nipype.interface INFO:
# 	 stdout 2019-02-01T13:25:38.409206:299840 299840.000000
# 190201-13:25:38,514 nipype.workflow INFO:
# 	 [Node] Finished "fs_wm".
# 190201-13:25:38,517 nipype.workflow INFO:
# 	 [Node] Setting-up "fs_gm" in "/private/var/folders/k9/m1nc7p5j71sfrw3hj1cg7jlr0000gn/T/tmp__rgrrfo/fs_gm".
# 190201-13:25:38,521 nipype.workflow INFO:
# 	 [Node] Running "fs_gm" ("nipype.interfaces.fsl.utils.ImageStats"), a CommandLine Interface with command:
# fslstats /Volumes/group/active/BABIES/BABIES_ibeat/Segmentation/Segmented_IdeaLab/045-C-T1_GMWM.nii.gz -l 149 -u 151 -V
# 190201-13:25:39,448 nipype.interface INFO:
# 	 stdout 2019-02-01T13:25:39.448501:375846 375846.000000
# 190201-13:25:39,558 nipype.workflow INFO:
# 	 [Node] Finished "fs_gm".
# 190201-13:25:39,560 nipype.workflow INFO:
# 	 [Node] Setting-up "fs_gm" in "/private/var/folders/k9/m1nc7p5j71sfrw3hj1cg7jlr0000gn/T/tmpwhfykek1/fs_gm".
# 190201-13:25:39,564 nipype.workflow INFO:
# 	 [Node] Running "fs_gm" ("nipype.interfaces.fsl.utils.ImageStats"), a CommandLine Interface with command:
# fslstats /Volumes/group/active/BABIES/BABIES_ibeat/Segmentation/Segmented_IdeaLab/045-C-T1_GMWM.nii.gz -l 149 -u 251 -V
# 190201-13:25:40,490 nipype.interface INFO:
# 	 stdout 2019-02-01T13:25:40.490035:675686 675686.000000
# 190201-13:25:40,596 nipype.workflow INFO:
# 	 [Node] Finished "fs_gm".
# 190201-13:25:40,601 nipype.workflow INFO:
# 	 [Node] Setting-up "fs_wm" in "/private/var/folders/k9/m1nc7p5j71sfrw3hj1cg7jlr0000gn/T/tmpu2pqi80l/fs_wm".
# 190201-13:25:40,605 nipype.workflow INFO:
# 	 [Node] Running "fs_wm" ("nipype.interfaces.fsl.utils.ImageStats"), a CommandLine Interface with command:
# fslstats /Volumes/group/active/BABIES/BABIES_ibeat/Segmentation/Segmented_IdeaLab/025-C-T1_GMWM.nii.gz -l 249 -u 251 -V
# 190201-13:25:41,515 nipype.interface INFO:
# 	 stdout 2019-02-01T13:25:41.515792:264579 264579.000000
# 190201-13:25:41,620 nipype.workflow INFO:
# 	 [Node] Finished "fs_wm".
# 190201-13:25:41,622 nipype.workflow INFO:
# 	 [Node] Setting-up "fs_gm" in "/private/var/folders/k9/m1nc7p5j71sfrw3hj1cg7jlr0000gn/T/tmp8q_fyki3/fs_gm".
# 190201-13:25:41,626 nipype.workflow INFO:
# 	 [Node] Running "fs_gm" ("nipype.interfaces.fsl.utils.ImageStats"), a CommandLine Interface with command:
# fslstats /Volumes/group/active/BABIES/BABIES_ibeat/Segmentation/Segmented_IdeaLab/025-C-T1_GMWM.nii.gz -l 149 -u 151 -V
# 190201-13:25:42,527 nipype.interface INFO:
# 	 stdout 2019-02-01T13:25:42.527786:324404 324404.000000
# 190201-13:25:42,633 nipype.workflow INFO:
# 	 [Node] Finished "fs_gm".
# 190201-13:25:42,635 nipype.workflow INFO:
# 	 [Node] Setting-up "fs_gm" in "/private/var/folders/k9/m1nc7p5j71sfrw3hj1cg7jlr0000gn/T/tmpi83k94t4/fs_gm".
# 190201-13:25:42,639 nipype.workflow INFO:
# 	 [Node] Running "fs_gm" ("nipype.interfaces.fsl.utils.ImageStats"), a CommandLine Interface with command:
# fslstats /Volumes/group/active/BABIES/BABIES_ibeat/Segmentation/Segmented_IdeaLab/025-C-T1_GMWM.nii.gz -l 149 -u 251 -V
# 190201-13:25:43,547 nipype.interface INFO:
# 	 stdout 2019-02-01T13:25:43.547276:588983 588983.000000
# 190201-13:25:43,658 nipype.workflow INFO:
# 	 [Node] Finished "fs_gm".
# 190201-13:25:43,664 nipype.workflow INFO:
# 	 [Node] Setting-up "fs_wm" in "/private/var/folders/k9/m1nc7p5j71sfrw3hj1cg7jlr0000gn/T/tmphxpq1x89/fs_wm".
# 190201-13:25:43,668 nipype.workflow INFO:
# 	 [Node] Running "fs_wm" ("nipype.interfaces.fsl.utils.ImageStats"), a CommandLine Interface with command:
# fslstats /Volumes/group/active/BABIES/BABIES_ibeat/Segmentation/Segmented_IdeaLab/129-C-T1_GMWM.nii.gz -l 249 -u 251 -V
# 190201-13:25:44,639 nipype.interface INFO:
# 	 stdout 2019-02-01T13:25:44.639299:272685 272685.000000
# 190201-13:25:44,747 nipype.workflow INFO:
# 	 [Node] Finished "fs_wm".
# 190201-13:25:44,750 nipype.workflow INFO:
# 	 [Node] Setting-up "fs_gm" in "/private/var/folders/k9/m1nc7p5j71sfrw3hj1cg7jlr0000gn/T/tmp9r6js0ps/fs_gm".
# 190201-13:25:44,754 nipype.workflow INFO:
# 	 [Node] Running "fs_gm" ("nipype.interfaces.fsl.utils.ImageStats"), a CommandLine Interface with command:
# fslstats /Volumes/group/active/BABIES/BABIES_ibeat/Segmentation/Segmented_IdeaLab/129-C-T1_GMWM.nii.gz -l 149 -u 151 -V
# 190201-13:25:45,679 nipype.interface INFO:
# 	 stdout 2019-02-01T13:25:45.678927:348991 348991.000000
# 190201-13:25:45,785 nipype.workflow INFO:
# 	 [Node] Finished "fs_gm".
# 190201-13:25:45,787 nipype.workflow INFO:
# 	 [Node] Setting-up "fs_gm" in "/private/var/folders/k9/m1nc7p5j71sfrw3hj1cg7jlr0000gn/T/tmpdxum9tho/fs_gm".
# 190201-13:25:45,791 nipype.workflow INFO:
# 	 [Node] Running "fs_gm" ("nipype.interfaces.fsl.utils.ImageStats"), a CommandLine Interface with command:
# fslstats /Volumes/group/active/BABIES/BABIES_ibeat/Segmentation/Segmented_IdeaLab/129-C-T1_GMWM.nii.gz -l 149 -u 251 -V
# 190201-13:25:46,682 nipype.interface INFO:
# 	 stdout 2019-02-01T13:25:46.682300:621676 621676.000000
# 190201-13:25:46,783 nipype.workflow INFO:
# 	 [Node] Finished "fs_gm".
# 190201-13:25:46,788 nipype.workflow INFO:
# 	 [Node] Setting-up "fs_wm" in "/private/var/folders/k9/m1nc7p5j71sfrw3hj1cg7jlr0000gn/T/tmpcw5kwgm3/fs_wm".
# 190201-13:25:46,792 nipype.workflow INFO:
# 	 [Node] Running "fs_wm" ("nipype.interfaces.fsl.utils.ImageStats"), a CommandLine Interface with command:
# fslstats /Volumes/group/active/BABIES/BABIES_ibeat/Segmentation/Segmented_IdeaLab/031-C-T1_GMWM.nii.gz -l 249 -u 251 -V
# 190201-13:25:47,696 nipype.interface INFO:
# 	 stdout 2019-02-01T13:25:47.695979:292401 292401.000000
# 190201-13:25:47,802 nipype.workflow INFO:
# 	 [Node] Finished "fs_wm".
# 190201-13:25:47,804 nipype.workflow INFO:
# 	 [Node] Setting-up "fs_gm" in "/private/var/folders/k9/m1nc7p5j71sfrw3hj1cg7jlr0000gn/T/tmpdavuwe_9/fs_gm".
# 190201-13:25:47,808 nipype.workflow INFO:
# 	 [Node] Running "fs_gm" ("nipype.interfaces.fsl.utils.ImageStats"), a CommandLine Interface with command:
# fslstats /Volumes/group/active/BABIES/BABIES_ibeat/Segmentation/Segmented_IdeaLab/031-C-T1_GMWM.nii.gz -l 149 -u 151 -V
# 190201-13:25:48,721 nipype.interface INFO:
# 	 stdout 2019-02-01T13:25:48.720972:371822 371822.000000
# 190201-13:25:48,826 nipype.workflow INFO:
# 	 [Node] Finished "fs_gm".
# 190201-13:25:48,828 nipype.workflow INFO:
# 	 [Node] Setting-up "fs_gm" in "/private/var/folders/k9/m1nc7p5j71sfrw3hj1cg7jlr0000gn/T/tmp5_vdfg5i/fs_gm".
# 190201-13:25:48,832 nipype.workflow INFO:
# 	 [Node] Running "fs_gm" ("nipype.interfaces.fsl.utils.ImageStats"), a CommandLine Interface with command:
# fslstats /Volumes/group/active/BABIES/BABIES_ibeat/Segmentation/Segmented_IdeaLab/031-C-T1_GMWM.nii.gz -l 149 -u 251 -V
# 190201-13:25:49,726 nipype.interface INFO:
# 	 stdout 2019-02-01T13:25:49.726117:664223 664223.000000
# 190201-13:25:49,834 nipype.workflow INFO:
# 	 [Node] Finished "fs_gm".
# 190201-13:25:49,839 nipype.workflow INFO:
# 	 [Node] Setting-up "fs_wm" in "/private/var/folders/k9/m1nc7p5j71sfrw3hj1cg7jlr0000gn/T/tmpa315tnl2/fs_wm".
# 190201-13:25:49,843 nipype.workflow INFO:
# 	 [Node] Running "fs_wm" ("nipype.interfaces.fsl.utils.ImageStats"), a CommandLine Interface with command:
# fslstats /Volumes/group/active/BABIES/BABIES_ibeat/Segmentation/Segmented_IdeaLab/036-C-T1_GMWM.nii.gz -l 249 -u 251 -V
# 190201-13:25:50,748 nipype.interface INFO:
# 	 stdout 2019-02-01T13:25:50.748825:362089 362089.000000
# 190201-13:25:50,856 nipype.workflow INFO:
# 	 [Node] Finished "fs_wm".
# 190201-13:25:50,859 nipype.workflow INFO:
# 	 [Node] Setting-up "fs_gm" in "/private/var/folders/k9/m1nc7p5j71sfrw3hj1cg7jlr0000gn/T/tmpywvw9mcv/fs_gm".
# 190201-13:25:50,863 nipype.workflow INFO:
# 	 [Node] Running "fs_gm" ("nipype.interfaces.fsl.utils.ImageStats"), a CommandLine Interface with command:
# fslstats /Volumes/group/active/BABIES/BABIES_ibeat/Segmentation/Segmented_IdeaLab/036-C-T1_GMWM.nii.gz -l 149 -u 151 -V
# 190201-13:25:51,778 nipype.interface INFO:
# 	 stdout 2019-02-01T13:25:51.777880:456908 456908.000000
# 190201-13:25:51,882 nipype.workflow INFO:
# 	 [Node] Finished "fs_gm".
# 190201-13:25:51,885 nipype.workflow INFO:
# 	 [Node] Setting-up "fs_gm" in "/private/var/folders/k9/m1nc7p5j71sfrw3hj1cg7jlr0000gn/T/tmpo09mddut/fs_gm".
# 190201-13:25:51,889 nipype.workflow INFO:
# 	 [Node] Running "fs_gm" ("nipype.interfaces.fsl.utils.ImageStats"), a CommandLine Interface with command:
# fslstats /Volumes/group/active/BABIES/BABIES_ibeat/Segmentation/Segmented_IdeaLab/036-C-T1_GMWM.nii.gz -l 149 -u 251 -V
# 190201-13:25:52,791 nipype.interface INFO:
# 	 stdout 2019-02-01T13:25:52.791091:818997 818997.000000
# 190201-13:25:52,896 nipype.workflow INFO:
# 	 [Node] Finished "fs_gm".
# 190201-13:25:52,901 nipype.workflow INFO:
# 	 [Node] Setting-up "fs_wm" in "/private/var/folders/k9/m1nc7p5j71sfrw3hj1cg7jlr0000gn/T/tmp1gz6qhjw/fs_wm".
# 190201-13:25:52,905 nipype.workflow INFO:
# 	 [Node] Running "fs_wm" ("nipype.interfaces.fsl.utils.ImageStats"), a CommandLine Interface with command:
# fslstats /Volumes/group/active/BABIES/BABIES_ibeat/Segmentation/Segmented_IdeaLab/1027-L-T3_GMWM.nii.gz -l 249 -u 251 -V
# 190201-13:25:53,804 nipype.interface INFO:
# 	 stdout 2019-02-01T13:25:53.804797:244470 244470.000000
# 190201-13:25:53,907 nipype.workflow INFO:
# 	 [Node] Finished "fs_wm".
# 190201-13:25:53,910 nipype.workflow INFO:
# 	 [Node] Setting-up "fs_gm" in "/private/var/folders/k9/m1nc7p5j71sfrw3hj1cg7jlr0000gn/T/tmpkic23d_m/fs_gm".
# 190201-13:25:53,914 nipype.workflow INFO:
# 	 [Node] Running "fs_gm" ("nipype.interfaces.fsl.utils.ImageStats"), a CommandLine Interface with command:
# fslstats /Volumes/group/active/BABIES/BABIES_ibeat/Segmentation/Segmented_IdeaLab/1027-L-T3_GMWM.nii.gz -l 149 -u 151 -V
# 190201-13:25:54,827 nipype.interface INFO:
# 	 stdout 2019-02-01T13:25:54.827270:306938 306938.000000
# 190201-13:25:54,928 nipype.workflow INFO:
# 	 [Node] Finished "fs_gm".
# 190201-13:25:54,930 nipype.workflow INFO:
# 	 [Node] Setting-up "fs_gm" in "/private/var/folders/k9/m1nc7p5j71sfrw3hj1cg7jlr0000gn/T/tmp3khpzbp0/fs_gm".
# 190201-13:25:54,935 nipype.workflow INFO:
# 	 [Node] Running "fs_gm" ("nipype.interfaces.fsl.utils.ImageStats"), a CommandLine Interface with command:
# fslstats /Volumes/group/active/BABIES/BABIES_ibeat/Segmentation/Segmented_IdeaLab/1027-L-T3_GMWM.nii.gz -l 149 -u 251 -V
# 190201-13:25:55,823 nipype.interface INFO:
# 	 stdout 2019-02-01T13:25:55.823351:551408 551408.000000
# 190201-13:25:55,925 nipype.workflow INFO:
# 	 [Node] Finished "fs_gm".
# 190201-13:25:55,930 nipype.workflow INFO:
# 	 [Node] Setting-up "fs_wm" in "/private/var/folders/k9/m1nc7p5j71sfrw3hj1cg7jlr0000gn/T/tmpnn6_lbcf/fs_wm".
# 190201-13:25:55,933 nipype.workflow INFO:
# 	 [Node] Running "fs_wm" ("nipype.interfaces.fsl.utils.ImageStats"), a CommandLine Interface with command:
# fslstats /Volumes/group/active/BABIES/BABIES_ibeat/Segmentation/Segmented_IdeaLab/040-C-T1_GMWM.nii.gz -l 249 -u 251 -V
# 190201-13:25:56,853 nipype.interface INFO:
# 	 stdout 2019-02-01T13:25:56.853729:313301 313301.000000
# 190201-13:25:56,959 nipype.workflow INFO:
# 	 [Node] Finished "fs_wm".
# 190201-13:25:56,962 nipype.workflow INFO:
# 	 [Node] Setting-up "fs_gm" in "/private/var/folders/k9/m1nc7p5j71sfrw3hj1cg7jlr0000gn/T/tmp3dh4wfeq/fs_gm".
# 190201-13:25:56,966 nipype.workflow INFO:
# 	 [Node] Running "fs_gm" ("nipype.interfaces.fsl.utils.ImageStats"), a CommandLine Interface with command:
# fslstats /Volumes/group/active/BABIES/BABIES_ibeat/Segmentation/Segmented_IdeaLab/040-C-T1_GMWM.nii.gz -l 149 -u 151 -V
# 190201-13:25:57,868 nipype.interface INFO:
# 	 stdout 2019-02-01T13:25:57.868009:370521 370521.000000
# 190201-13:25:57,972 nipype.workflow INFO:
# 	 [Node] Finished "fs_gm".
# 190201-13:25:57,975 nipype.workflow INFO:
# 	 [Node] Setting-up "fs_gm" in "/private/var/folders/k9/m1nc7p5j71sfrw3hj1cg7jlr0000gn/T/tmppw7e13ud/fs_gm".
# 190201-13:25:57,979 nipype.workflow INFO:
# 	 [Node] Running "fs_gm" ("nipype.interfaces.fsl.utils.ImageStats"), a CommandLine Interface with command:
# fslstats /Volumes/group/active/BABIES/BABIES_ibeat/Segmentation/Segmented_IdeaLab/040-C-T1_GMWM.nii.gz -l 149 -u 251 -V
# 190201-13:25:58,881 nipype.interface INFO:
# 	 stdout 2019-02-01T13:25:58.881808:683822 683822.000000
# 190201-13:25:58,986 nipype.workflow INFO:
# 	 [Node] Finished "fs_gm".
# 190201-13:25:58,991 nipype.workflow INFO:
# 	 [Node] Setting-up "fs_wm" in "/private/var/folders/k9/m1nc7p5j71sfrw3hj1cg7jlr0000gn/T/tmp0bzracd0/fs_wm".
# 190201-13:25:58,995 nipype.workflow INFO:
# 	 [Node] Running "fs_wm" ("nipype.interfaces.fsl.utils.ImageStats"), a CommandLine Interface with command:
# fslstats /Volumes/group/active/BABIES/BABIES_ibeat/Segmentation/Segmented_IdeaLab/110-C-T1_GMWM.nii.gz -l 249 -u 251 -V
# 190201-13:25:59,907 nipype.interface INFO:
# 	 stdout 2019-02-01T13:25:59.906831:267562 267562.000000
# 190201-13:26:00,9 nipype.workflow INFO:
# 	 [Node] Finished "fs_wm".
# 190201-13:26:00,11 nipype.workflow INFO:
# 	 [Node] Setting-up "fs_gm" in "/private/var/folders/k9/m1nc7p5j71sfrw3hj1cg7jlr0000gn/T/tmpzpohizc0/fs_gm".
# 190201-13:26:00,16 nipype.workflow INFO:
# 	 [Node] Running "fs_gm" ("nipype.interfaces.fsl.utils.ImageStats"), a CommandLine Interface with command:
# fslstats /Volumes/group/active/BABIES/BABIES_ibeat/Segmentation/Segmented_IdeaLab/110-C-T1_GMWM.nii.gz -l 149 -u 151 -V
# 190201-13:26:00,952 nipype.interface INFO:
# 	 stdout 2019-02-01T13:26:00.952530:341501 341501.000000
# 190201-13:26:01,59 nipype.workflow INFO:
# 	 [Node] Finished "fs_gm".
# 190201-13:26:01,62 nipype.workflow INFO:
# 	 [Node] Setting-up "fs_gm" in "/private/var/folders/k9/m1nc7p5j71sfrw3hj1cg7jlr0000gn/T/tmpf9wbgyz_/fs_gm".
# 190201-13:26:01,66 nipype.workflow INFO:
# 	 [Node] Running "fs_gm" ("nipype.interfaces.fsl.utils.ImageStats"), a CommandLine Interface with command:
# fslstats /Volumes/group/active/BABIES/BABIES_ibeat/Segmentation/Segmented_IdeaLab/110-C-T1_GMWM.nii.gz -l 149 -u 251 -V
# 190201-13:26:02,27 nipype.interface INFO:
# 	 stdout 2019-02-01T13:26:02.027592:609063 609063.000000
# 190201-13:26:02,136 nipype.workflow INFO:
# 	 [Node] Finished "fs_gm".
# 190201-13:26:02,141 nipype.workflow INFO:
# 	 [Node] Setting-up "fs_wm" in "/private/var/folders/k9/m1nc7p5j71sfrw3hj1cg7jlr0000gn/T/tmppg_fsp4l/fs_wm".
# 190201-13:26:02,145 nipype.workflow INFO:
# 	 [Node] Running "fs_wm" ("nipype.interfaces.fsl.utils.ImageStats"), a CommandLine Interface with command:
# fslstats /Volumes/group/active/BABIES/BABIES_ibeat/Segmentation/Segmented_IdeaLab/023-C-T1_GMWM.nii.gz -l 249 -u 251 -V
# 190201-13:26:03,99 nipype.interface INFO:
# 	 stdout 2019-02-01T13:26:03.099383:246027 246027.000000
# 190201-13:26:03,208 nipype.workflow INFO:
# 	 [Node] Finished "fs_wm".
# 190201-13:26:03,211 nipype.workflow INFO:
# 	 [Node] Setting-up "fs_gm" in "/private/var/folders/k9/m1nc7p5j71sfrw3hj1cg7jlr0000gn/T/tmp0zuull4k/fs_gm".
# 190201-13:26:03,215 nipype.workflow INFO:
# 	 [Node] Running "fs_gm" ("nipype.interfaces.fsl.utils.ImageStats"), a CommandLine Interface with command:
# fslstats /Volumes/group/active/BABIES/BABIES_ibeat/Segmentation/Segmented_IdeaLab/023-C-T1_GMWM.nii.gz -l 149 -u 151 -V
# 190201-13:26:04,152 nipype.interface INFO:
# 	 stdout 2019-02-01T13:26:04.152335:334959 334959.000000
# 190201-13:26:04,258 nipype.workflow INFO:
# 	 [Node] Finished "fs_gm".
# 190201-13:26:04,261 nipype.workflow INFO:
# 	 [Node] Setting-up "fs_gm" in "/private/var/folders/k9/m1nc7p5j71sfrw3hj1cg7jlr0000gn/T/tmpvr_p4drf/fs_gm".
# 190201-13:26:04,265 nipype.workflow INFO:
# 	 [Node] Running "fs_gm" ("nipype.interfaces.fsl.utils.ImageStats"), a CommandLine Interface with command:
# fslstats /Volumes/group/active/BABIES/BABIES_ibeat/Segmentation/Segmented_IdeaLab/023-C-T1_GMWM.nii.gz -l 149 -u 251 -V
# 190201-13:26:05,531 nipype.interface INFO:
# 	 stdout 2019-02-01T13:26:05.531595:580986 580986.000000
# 190201-13:26:05,639 nipype.workflow INFO:
# 	 [Node] Finished "fs_gm".
# 190201-13:26:05,644 nipype.workflow INFO:
# 	 [Node] Setting-up "fs_wm" in "/private/var/folders/k9/m1nc7p5j71sfrw3hj1cg7jlr0000gn/T/tmpl_0xfqm1/fs_wm".
# 190201-13:26:05,648 nipype.workflow INFO:
# 	 [Node] Running "fs_wm" ("nipype.interfaces.fsl.utils.ImageStats"), a CommandLine Interface with command:
# fslstats /Volumes/group/active/BABIES/BABIES_ibeat/Segmentation/Segmented_IdeaLab/020-C-T1_GMWM.nii.gz -l 249 -u 251 -V
# 190201-13:26:06,566 nipype.interface INFO:
# 	 stdout 2019-02-01T13:26:06.566378:256651 256651.000000
# 190201-13:26:06,670 nipype.workflow INFO:
# 	 [Node] Finished "fs_wm".
# 190201-13:26:06,673 nipype.workflow INFO:
# 	 [Node] Setting-up "fs_gm" in "/private/var/folders/k9/m1nc7p5j71sfrw3hj1cg7jlr0000gn/T/tmpblbrq9ux/fs_gm".
# 190201-13:26:06,677 nipype.workflow INFO:
# 	 [Node] Running "fs_gm" ("nipype.interfaces.fsl.utils.ImageStats"), a CommandLine Interface with command:
# fslstats /Volumes/group/active/BABIES/BABIES_ibeat/Segmentation/Segmented_IdeaLab/020-C-T1_GMWM.nii.gz -l 149 -u 151 -V
# 190201-13:26:07,631 nipype.interface INFO:
# 	 stdout 2019-02-01T13:26:07.631513:321110 321110.000000
# 190201-13:26:07,739 nipype.workflow INFO:
# 	 [Node] Finished "fs_gm".
# 190201-13:26:07,742 nipype.workflow INFO:
# 	 [Node] Setting-up "fs_gm" in "/private/var/folders/k9/m1nc7p5j71sfrw3hj1cg7jlr0000gn/T/tmp4114t6y0/fs_gm".
# 190201-13:26:07,746 nipype.workflow INFO:
# 	 [Node] Running "fs_gm" ("nipype.interfaces.fsl.utils.ImageStats"), a CommandLine Interface with command:
# fslstats /Volumes/group/active/BABIES/BABIES_ibeat/Segmentation/Segmented_IdeaLab/020-C-T1_GMWM.nii.gz -l 149 -u 251 -V
# 190201-13:26:08,670 nipype.interface INFO:
# 	 stdout 2019-02-01T13:26:08.670272:577761 577761.000000
# 190201-13:26:08,805 nipype.workflow INFO:
# 	 [Node] Finished "fs_gm".
# 190201-13:26:08,811 nipype.workflow INFO:
# 	 [Node] Setting-up "fs_wm" in "/private/var/folders/k9/m1nc7p5j71sfrw3hj1cg7jlr0000gn/T/tmpo69597wc/fs_wm".
# 190201-13:26:08,815 nipype.workflow INFO:
# 	 [Node] Running "fs_wm" ("nipype.interfaces.fsl.utils.ImageStats"), a CommandLine Interface with command:
# fslstats /Volumes/group/active/BABIES/BABIES_ibeat/Segmentation/Segmented_IdeaLab/1024-L-T3_GMWM.nii.gz -l 249 -u 251 -V
# 190201-13:26:09,831 nipype.interface INFO:
# 	 stdout 2019-02-01T13:26:09.831226:296301 296301.000000
# 190201-13:26:09,947 nipype.workflow INFO:
# 	 [Node] Finished "fs_wm".
# 190201-13:26:09,950 nipype.workflow INFO:
# 	 [Node] Setting-up "fs_gm" in "/private/var/folders/k9/m1nc7p5j71sfrw3hj1cg7jlr0000gn/T/tmpecp2rxey/fs_gm".
# 190201-13:26:09,954 nipype.workflow INFO:
# 	 [Node] Running "fs_gm" ("nipype.interfaces.fsl.utils.ImageStats"), a CommandLine Interface with command:
# fslstats /Volumes/group/active/BABIES/BABIES_ibeat/Segmentation/Segmented_IdeaLab/1024-L-T3_GMWM.nii.gz -l 149 -u 151 -V
# 190201-13:26:10,905 nipype.interface INFO:
# 	 stdout 2019-02-01T13:26:10.905476:378281 378281.000000
# 190201-13:26:11,8 nipype.workflow INFO:
# 	 [Node] Finished "fs_gm".
# 190201-13:26:11,11 nipype.workflow INFO:
# 	 [Node] Setting-up "fs_gm" in "/private/var/folders/k9/m1nc7p5j71sfrw3hj1cg7jlr0000gn/T/tmpm_xep4f7/fs_gm".
# 190201-13:26:11,15 nipype.workflow INFO:
# 	 [Node] Running "fs_gm" ("nipype.interfaces.fsl.utils.ImageStats"), a CommandLine Interface with command:
# fslstats /Volumes/group/active/BABIES/BABIES_ibeat/Segmentation/Segmented_IdeaLab/1024-L-T3_GMWM.nii.gz -l 149 -u 251 -V
# 190201-13:26:11,937 nipype.interface INFO:
# 	 stdout 2019-02-01T13:26:11.937235:674582 674582.000000
# 190201-13:26:12,41 nipype.workflow INFO:
# 	 [Node] Finished "fs_gm".
# 190201-13:26:12,46 nipype.workflow INFO:
# 	 [Node] Setting-up "fs_wm" in "/private/var/folders/k9/m1nc7p5j71sfrw3hj1cg7jlr0000gn/T/tmp6j2lflr2/fs_wm".
# 190201-13:26:12,50 nipype.workflow INFO:
# 	 [Node] Running "fs_wm" ("nipype.interfaces.fsl.utils.ImageStats"), a CommandLine Interface with command:
# fslstats /Volumes/group/active/BABIES/BABIES_ibeat/Segmentation/Segmented_IdeaLab/035-C-T1_GMWM.nii.gz -l 249 -u 251 -V
# 190201-13:26:12,973 nipype.interface INFO:
# 	 stdout 2019-02-01T13:26:12.972928:257908 257908.000000
# 190201-13:26:13,76 nipype.workflow INFO:
# 	 [Node] Finished "fs_wm".
# 190201-13:26:13,78 nipype.workflow INFO:
# 	 [Node] Setting-up "fs_gm" in "/private/var/folders/k9/m1nc7p5j71sfrw3hj1cg7jlr0000gn/T/tmpgegi56hs/fs_gm".
# 190201-13:26:13,82 nipype.workflow INFO:
# 	 [Node] Running "fs_gm" ("nipype.interfaces.fsl.utils.ImageStats"), a CommandLine Interface with command:
# fslstats /Volumes/group/active/BABIES/BABIES_ibeat/Segmentation/Segmented_IdeaLab/035-C-T1_GMWM.nii.gz -l 149 -u 151 -V
# 190201-13:26:14,7 nipype.interface INFO:
# 	 stdout 2019-02-01T13:26:14.007521:329523 329523.000000
# 190201-13:26:14,110 nipype.workflow INFO:
# 	 [Node] Finished "fs_gm".
# 190201-13:26:14,113 nipype.workflow INFO:
# 	 [Node] Setting-up "fs_gm" in "/private/var/folders/k9/m1nc7p5j71sfrw3hj1cg7jlr0000gn/T/tmpm4siye31/fs_gm".
# 190201-13:26:14,117 nipype.workflow INFO:
# 	 [Node] Running "fs_gm" ("nipype.interfaces.fsl.utils.ImageStats"), a CommandLine Interface with command:
# fslstats /Volumes/group/active/BABIES/BABIES_ibeat/Segmentation/Segmented_IdeaLab/035-C-T1_GMWM.nii.gz -l 149 -u 251 -V
# 190201-13:26:15,71 nipype.interface INFO:
# 	 stdout 2019-02-01T13:26:15.070927:587431 587431.000000
# 190201-13:26:15,175 nipype.workflow INFO:
# 	 [Node] Finished "fs_gm".
# 190201-13:26:15,180 nipype.workflow INFO:
# 	 [Node] Setting-up "fs_wm" in "/private/var/folders/k9/m1nc7p5j71sfrw3hj1cg7jlr0000gn/T/tmp7hlcxrba/fs_wm".
# 190201-13:26:15,184 nipype.workflow INFO:
# 	 [Node] Running "fs_wm" ("nipype.interfaces.fsl.utils.ImageStats"), a CommandLine Interface with command:
# fslstats /Volumes/group/active/BABIES/BABIES_ibeat/Segmentation/Segmented_IdeaLab/021-C-T1_GMWM.nii.gz -l 249 -u 251 -V
# 190201-13:26:16,120 nipype.interface INFO:
# 	 stdout 2019-02-01T13:26:16.120602:278254 278254.000000
# 190201-13:26:16,226 nipype.workflow INFO:
# 	 [Node] Finished "fs_wm".
# 190201-13:26:16,228 nipype.workflow INFO:
# 	 [Node] Setting-up "fs_gm" in "/private/var/folders/k9/m1nc7p5j71sfrw3hj1cg7jlr0000gn/T/tmpwiktdynf/fs_gm".
# 190201-13:26:16,232 nipype.workflow INFO:
# 	 [Node] Running "fs_gm" ("nipype.interfaces.fsl.utils.ImageStats"), a CommandLine Interface with command:
# fslstats /Volumes/group/active/BABIES/BABIES_ibeat/Segmentation/Segmented_IdeaLab/021-C-T1_GMWM.nii.gz -l 149 -u 151 -V
# 190201-13:26:17,152 nipype.interface INFO:
# 	 stdout 2019-02-01T13:26:17.152610:334349 334349.000000
# 190201-13:26:17,263 nipype.workflow INFO:
# 	 [Node] Finished "fs_gm".
# 190201-13:26:17,265 nipype.workflow INFO:
# 	 [Node] Setting-up "fs_gm" in "/private/var/folders/k9/m1nc7p5j71sfrw3hj1cg7jlr0000gn/T/tmp17x7ev6k/fs_gm".
# 190201-13:26:17,269 nipype.workflow INFO:
# 	 [Node] Running "fs_gm" ("nipype.interfaces.fsl.utils.ImageStats"), a CommandLine Interface with command:
# fslstats /Volumes/group/active/BABIES/BABIES_ibeat/Segmentation/Segmented_IdeaLab/021-C-T1_GMWM.nii.gz -l 149 -u 251 -V
# 190201-13:26:18,212 nipype.interface INFO:
# 	 stdout 2019-02-01T13:26:18.212428:612603 612603.000000
# 190201-13:26:18,325 nipype.workflow INFO:
# 	 [Node] Finished "fs_gm".
# 190201-13:26:18,330 nipype.workflow INFO:
# 	 [Node] Setting-up "fs_wm" in "/private/var/folders/k9/m1nc7p5j71sfrw3hj1cg7jlr0000gn/T/tmpl5zwhx40/fs_wm".
# 190201-13:26:18,335 nipype.workflow INFO:
# 	 [Node] Running "fs_wm" ("nipype.interfaces.fsl.utils.ImageStats"), a CommandLine Interface with command:
# fslstats /Volumes/group/active/BABIES/BABIES_ibeat/Segmentation/Segmented_IdeaLab/112-C-T1_GMWM.nii.gz -l 249 -u 251 -V
# 190201-13:26:19,330 nipype.interface INFO:
# 	 stdout 2019-02-01T13:26:19.330526:274817 274817.000000
# 190201-13:26:19,457 nipype.workflow INFO:
# 	 [Node] Finished "fs_wm".
# 190201-13:26:19,460 nipype.workflow INFO:
# 	 [Node] Setting-up "fs_gm" in "/private/var/folders/k9/m1nc7p5j71sfrw3hj1cg7jlr0000gn/T/tmp9sh9vewk/fs_gm".
# 190201-13:26:19,464 nipype.workflow INFO:
# 	 [Node] Running "fs_gm" ("nipype.interfaces.fsl.utils.ImageStats"), a CommandLine Interface with command:
# fslstats /Volumes/group/active/BABIES/BABIES_ibeat/Segmentation/Segmented_IdeaLab/112-C-T1_GMWM.nii.gz -l 149 -u 151 -V
# 190201-13:26:20,473 nipype.interface INFO:
# 	 stdout 2019-02-01T13:26:20.473727:356066 356066.000000
# 190201-13:26:20,585 nipype.workflow INFO:
# 	 [Node] Finished "fs_gm".
# 190201-13:26:20,589 nipype.workflow INFO:
# 	 [Node] Setting-up "fs_gm" in "/private/var/folders/k9/m1nc7p5j71sfrw3hj1cg7jlr0000gn/T/tmpxdm54_h7/fs_gm".
# 190201-13:26:20,593 nipype.workflow INFO:
# 	 [Node] Running "fs_gm" ("nipype.interfaces.fsl.utils.ImageStats"), a CommandLine Interface with command:
# fslstats /Volumes/group/active/BABIES/BABIES_ibeat/Segmentation/Segmented_IdeaLab/112-C-T1_GMWM.nii.gz -l 149 -u 251 -V
# 190201-13:26:21,649 nipype.interface INFO:
# 	 stdout 2019-02-01T13:26:21.649555:630883 630883.000000
# 190201-13:26:21,781 nipype.workflow INFO:
# 	 [Node] Finished "fs_gm".
# 190201-13:26:21,786 nipype.workflow INFO:
# 	 [Node] Setting-up "fs_wm" in "/private/var/folders/k9/m1nc7p5j71sfrw3hj1cg7jlr0000gn/T/tmpngn8xz34/fs_wm".
# 190201-13:26:21,791 nipype.workflow INFO:
# 	 [Node] Running "fs_wm" ("nipype.interfaces.fsl.utils.ImageStats"), a CommandLine Interface with command:
# fslstats /Volumes/group/active/BABIES/BABIES_ibeat/Segmentation/Segmented_IdeaLab/1078-L-T3_GMWM.nii.gz -l 249 -u 251 -V
# 190201-13:26:22,797 nipype.interface INFO:
# 	 stdout 2019-02-01T13:26:22.797423:277404 277404.000000
# 190201-13:26:22,915 nipype.workflow INFO:
# 	 [Node] Finished "fs_wm".
# 190201-13:26:22,918 nipype.workflow INFO:
# 	 [Node] Setting-up "fs_gm" in "/private/var/folders/k9/m1nc7p5j71sfrw3hj1cg7jlr0000gn/T/tmpt34n1x6m/fs_gm".
# 190201-13:26:22,922 nipype.workflow INFO:
# 	 [Node] Running "fs_gm" ("nipype.interfaces.fsl.utils.ImageStats"), a CommandLine Interface with command:
# fslstats /Volumes/group/active/BABIES/BABIES_ibeat/Segmentation/Segmented_IdeaLab/1078-L-T3_GMWM.nii.gz -l 149 -u 151 -V
# 190201-13:26:23,891 nipype.interface INFO:
# 	 stdout 2019-02-01T13:26:23.891338:355154 355154.000000
# 190201-13:26:24,1 nipype.workflow INFO:
# 	 [Node] Finished "fs_gm".
# 190201-13:26:24,3 nipype.workflow INFO:
# 	 [Node] Setting-up "fs_gm" in "/private/var/folders/k9/m1nc7p5j71sfrw3hj1cg7jlr0000gn/T/tmpq6uwgys8/fs_gm".
# 190201-13:26:24,7 nipype.workflow INFO:
# 	 [Node] Running "fs_gm" ("nipype.interfaces.fsl.utils.ImageStats"), a CommandLine Interface with command:
# fslstats /Volumes/group/active/BABIES/BABIES_ibeat/Segmentation/Segmented_IdeaLab/1078-L-T3_GMWM.nii.gz -l 149 -u 251 -V
# 190201-13:26:24,963 nipype.interface INFO:
# 	 stdout 2019-02-01T13:26:24.962963:632558 632558.000000
# 190201-13:26:25,74 nipype.workflow INFO:
# 	 [Node] Finished "fs_gm".

# %%
voxdf = DataFrame(data, columns = ['SUBID' , 'WM_volume_mm3', 'GM_volume_mm3' , 'GMWM_total_volume_mm3']).sort_values(by=['SUBID'])
voxdf.to_csv(dest + '/6mo_GM_WM_CorticalVolume'+today+'.csv', index=False)
